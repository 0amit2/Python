# %% [markdown]
# # DATA TYPE

# %% [markdown]
# ## primary datatype

# %%
# int -1,3 ,4,5,-34,34
# float: 23.34,4.5
# str: 'Amit','hello',"world",'a'
# bool: True,False
# Complex: 8+7j,3-4j

# %% [markdown]
# ## Secondary DATA TYPE

# %%
# List ,tuple , set , range , dict

# %% [markdown]
# ## Variable

# %%
#  a memory location given to some value
# variable_name = value
x=123
# x is variable
# 123 is value assigned to x

# %%
x=100
print(x)
# Out:
# 100

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
x="Amit"
print(x)
print(type(x))
# Out:
# Amit
# <class 'str'>

# %%
x=23.45
print(x)
print(type(x))
# Out:
# 23.45
# <class 'float'>

# %%
x=True
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>

# %%
x=False
print(x)
print(type(x))
# Out:
# False
# <class 'bool'>

# %%
x=3+6j
print(x)
print(type(x))
# Out:
# (3+6j)
# <class 'complex'>

# %%
x=5-6j
print(x)
print(type(x))
# Out:
# (5-6j)
# <class 'complex'>

# %%
y=88
print(y)
# Out:
# 88

# %%
x,y,z=3,4,'hi'
print(x,y,z)
# Out:
# 3 4 hi

# %%
_name="Amit"
print(_name)
# Out:
# Amit

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x=int(input("enter a number: "))
print(x)
# Out:
# enter a number:  45
# 45

# %%
x=float(input("enter float number:"))
print(x)
# Out:
# enter float number: 34.5
# 34.5

# %% [markdown]
# # Operators

# %% [markdown]
# ## Arthmatic Operators

# %%
# -,+,*,/,//,%,**

# %%
x=4
y=6
print(x+y,x-y,x*y,x/y)
# Out:
# 10 -2 24 0.6666666666666666

# %%
print(x//y)
print(x%y)
print(x**y)
# Out:
# 0
# 4
# 4096

# %%
x=9
print(x)
x += 1
print(x)
x -= 2
print(x)
x *= 2
print(x)
# Out:
# 9
# 10
# 8
# 16

# %%
num1=eval(input("enter number 1:"))
num2=eval(input("enter number 2:"))
num3=eval(input("enter number 3:"))
sum=(num1+num2+num3)
print(sum)
avg=sum/3
print(avg)
# Out:
# enter number 1: 3
# enter number 2: 4
# enter number 3: 5
# 12
# 4.0

# %%
product=num1*num2*num3
print(product)
# Out:
# 60

# %%
x=3
y=4
x,y=y,x
print(x,y)
# Out:
# 4 3

# %%
a=4
b=9
num=a
a=b
b=num
print(a,b)
# Out:
# 9 4

# %%
print(bin(100))
# Out:
# 0b1100100

# %%
print(bin(1))
# Out:
# 0b1
